# %%
import pandas as pd

# %%
df = pd.read_csv("C:/Users/Nishant Borkar/Downloads/archive (8)/text.csv")

# %%
df.head()
# Out:
#    Unnamed: 0                                               text  label
# 0           0      i just feel really helpless and heavy hearted      4
# 1           1  ive enjoyed being able to slouch about relax a...      0
# 2           2  i gave up my internship with the dmrg and am f...      4
# 3           3                         i dont know i feel so lost      0
# 4           4  i am a kindergarten teacher and i am thoroughl...      4

# %%
df.drop("Unnamed: 0", inplace=True, axis='columns')

# %%
df.head(2)
# Out:
#                                                 text  label
# 0      i just feel really helpless and heavy hearted      4
# 1  ive enjoyed being able to slouch about relax a...      0

# %%
df['text'][1]
# Out:
# 'ive enjoyed being able to slouch about relax and unwind and frankly needed it after those last few weeks around the end of uni and the expo i have lately started to find myself feeling a bit listless which is never really a good thing'

# %%
df['text'][2]
# Out:
# 'i gave up my internship with the dmrg and am feeling distraught'

# %%
import tensorflow as tf
import nltk

# %%
from nltk.stem import PorterStemmer
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import re
from tensorflow.keras.preprocessing.text import Tokenizer

nltk.download('stopwords')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package stopwords to C:\Users\Nishant
# [nltk_data]     Borkar\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# [nltk_data] Downloading package punkt to C:\Users\Nishant
# [nltk_data]     Borkar\AppData\Roaming\nltk_data...
# [nltk_data]   Unzipping tokenizers\punkt.zip.
# True

# %%
stemmer = PorterStemmer()
stop_words = set(stopwords.words('english'))

# %%
def clean_text(text):
    text = text.lower()
    text = re.sub(r'http\S+', '', text)
    text = re.sub(r'www\.\S+', '', text)
    text = re.sub(r'[^\w\s]', '', text)
    text = re.sub('\w*\d\w*', '', text)
    tokens = word_tokenize(text)
    # Remove stopwords and stem tokens
    cleaned_tokens = [stemmer.stem(token) for token in tokens if token not in stop_words]
    # Join the tokens back into a single string
    cleaned_text = ' '.join(cleaned_tokens)
    return cleaned_text

# %%
df['text'][2]
# Out:
# 'i gave up my internship with the dmrg and am feeling distraught'

# %%
df['clean_text'] = df['text'].apply(clean_text)

# %%
df.head(3)
# Out:
#                                                 text  label  \
# 0      i just feel really helpless and heavy hearted      4
# 1  ive enjoyed being able to slouch about relax a...      0
# 2  i gave up my internship with the dmrg and am f...      4
#
#                                           clean_text
# 0                   feel realli helpless heavi heart
# 1  ive enjoy abl slouch relax unwind frankli need...
# 2               gave internship dmrg feel distraught

# %%
tokeniz =  Tokenizer(num_words=50000)

# %%
tokeniz.fit_on_texts(df['clean_text'])

# %%
df['text'][0]
# Out:
# 'i just feel really helpless and heavy hearted'

# %%
df['text'][0]
# Out:
# 'i just feel really helpless and heavy hearted'

# %%
aa = tokeniz.texts_to_sequences(df['text'][0])

# %%
print(tokeniz.word_index)
# Out:
# {'i': 1, 'feel': 2, 'and': 3, 'to': 4, 'the': 5, 'a': 6, 'feeling': 7, 'that': 8, 'of': 9, 'my': 10, 'in': 11, 'it': 12, 'like': 13, 'so': 14, 'for': 15, 'im': 16, 'have': 17, 'me': 18, 'but': 19, 'was': 20, 'is': 21, 'this': 22, 'am': 23, 'with': 24, 'not': 25, 'be': 26, 'about': 27, 'as': 28, 'on': 29, 'you': 30, 'just': 31, 'when': 32, 'at': 33, 'or': 34, 'all': 35, 'because': 36, 'more': 37, 'do': 38, 'can': 39, 'really': 40, 'up': 41, 't': 42, 'know': 43, 'by': 44, 'are': 45, 'very': 46, 'been': 47, 'out': 48, 'myself': 49, 'what': 50, 'if': 51, 'time': 52, 'how': 53, 'get': 54, 'little': 55, 'will': 56, 'had': 57, 'now': 58, 'from': 59, 'being': 60, 'people': 61, 'they': 62, 'would': 63, 'he': 64, 'her': 65, 'want': 66, 'one': 67, 'think': 68, 'them': 69, 'still': 70, 'some': 71, 'ive': 72, 'even': 73, 'who': 74, 'much': 75, 'an': 76, 'we': 77, 'life': 78, 'him': 79, 'its': 80, 'there': 81, 'something': 82, 's': 83, 'things': 84, 'way': 85, 'bit': 86, 'm': 87, 'make': 88, 'love
# ...

# %%
# %pwd
# Out:
# 'd:\\Deepl learning project\\Emotion-Project\\Emotions-Classification\\research'

# %%
import os

# %%
os.chdir("..")

# %%
# %pwd
# Out:
# 'd:\\Deepl learning project\\Emotion-Project\\Emotions-Classification'

# %%
from src.emotion import logging, ModelException

# %%
logging.info("Ok Done")

# %%
from src.emotion.utils.common import read_yaml, save_json, create_directory
from pathlib import Path
import sys

# %%
a = read_yaml(file_path=Path("config/config.yaml"))

# %%
a.artifact_dir.data_ingenstion.root_dir
# Out:
# 'artifact/data_ingenstion'

# %%
try:
    from src.emotion.utils.common import save_json
except Exception as e:
    raise ModelException(e,sys)

# %%
data = {"data":"jadu", "data2":"jadu2"}

# %%
save_json(file_path=Path("jadu.json"),data=data)

# %%
list = ["artifact/data"]

# %%
create_directory(path_directory=list)

# %%
import os
from kaggle.api.kaggle_api_extended import KaggleApi
os.environ["KAGGLE_USERNAME"] = "nishantborkar"
os.environ["KAGGLE_KEY"] = "eabe1cc1ccb714e66ca20d6f06c2f757"

# %%
api = KaggleApi()

# %%
api.authenticate()

# %%
dataset = 'nelgiriyewithana/emotions'

# %%
api.dataset_download_files(dataset=dataset,path="aabc",unzip=True)
# Out:
# Dataset URL: https://www.kaggle.com/datasets/nelgiriyewithana/emotions

# %%
import os

# %%
os.environ["KAGGLE_KEY"]
# Out:
# 'eabe1cc1ccb714e66ca20d6f06c2f757'

# %%
os.environ["KAGGLE_USERNAME"]
# Out:
# 'username'
